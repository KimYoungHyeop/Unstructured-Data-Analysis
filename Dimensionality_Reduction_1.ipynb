# %% [markdown]
# # Dimensionality Reduction
#
# 해당 챕터에서는 Dimensionality Reduction의 개념과 Feature Selection 지표들에 대한 설명이 진행됩니다. 그리고 나서 Feature Extraction 관점에서 대표적인 잠재 의미 분석에 해당하는 LSA와 t-SNE 방법론에 대한 설명이 주요 AGENDA입니다.

# %% [markdown]
# ## < Dimensionality Reduction >
# ### Common features of text data
# - In general, a document consists of a large number of terms (words)
# - Only a few of them are actually relevant to text mining tasks even after some preprocessing (stop-words removal, stemming, lemmatization, etc)

# %% [markdown]
# 아래 그림은 TDM(Term Document Matrix)형태로 Term이 열이고, Document가 행인 데이터인데요.
#
# 이 데이터가 가지고 있는 문제점 중 첫 번째는 dimensionality가 크다는 것입니다.
# 조금 더 덧붙이면 terms의 개수가 documents의 개수보다 큰 경우가 많더라는 부분인데 일반적으로 통계학적인 관점에서 보면 관측치의 수가 최소한 변수의 수보다는 많아야지만 다중공산성(Multicollinearity)이라든지, 여러 통계적 가정을 만족할 가능성이 있습니다. 그런데 변수의 수가 관측치의 수보다 더 많아버리면 이러한 전통적인 통계적 방법을 사용하는 데에 무리가 따르게 됩니다.
#
# 문제점 두 번째는 효율성, 연산 관점에서 봤을 때의 'Sparseness'입니다.
# 이 Matrix의 대부분의 elements는 0이라는 것인데요 왜냐하면 term의 개수는 우리가 가지고 있는 언어에서의 전체 단어의 수라고 표현을 하자면 기껏해야 한 문서는 한 paragraph 당 100-200 단어로 구성이 된다면 영어가 13만 개의 단어가 있는 점을 고려하자면 100-200개 빼고 나머지는 모두 0이 되어 버리는, 즉 저장과 처리에서 매우 비효율적인 문제가 발생이 됩니다.

# %% [markdown]
# ![스크린샷 2022-06-11 오후 4.14.13.png](data:image/png;base64,...)

# %% [markdown]
# ### Why is dimensionality reduction necessary?
# - To make large problems ***computationally efficient*** (conserving computation, storage and network resources)
#
# ###To ***improve the quality*** of text mining results
# - Improve classification accuracy or clustering modularity
# - Reduce the amount of training data needed to obtain a desired level of performance

# %% [markdown]
# ### A simplified taxonomy of dimensionality reduction techniques

# %% [markdown]
# ![스크린샷 2022-06-11 오후 4.20.00.png](data:image/png;base64,...)

# %% [markdown]
# ### Feature selection vs. feature extraction
# - `Feature selection`: select a small subset of original variables
# - `Feature extraction`: construct/extract a new set of features based on the original variables

# %% [markdown]
# ![스크린샷 2022-06-11 오후 4.21.55.png](data:image/png;base64,...)

# %% [markdown]
# ### Filter approach vs. Wrapper approach
# - `Filter`: select a set of features based on pre-defined criteria
#    - no feedback loop, independent of the learning algorithm
#
#
# - `Wrapper`: evaluate a subset with a learning algorithm and repeat the process until a certain level of performance is achived
#    - Feedback loop exists, dependent on the learning algorithm

# %% [markdown]
# ![스크린샷 2022-06-11 오후 4.25.09.png](data:image/png;base64,...)
