# %% [markdown]
# # Text Representation I - Classic Methods

# %% [markdown]
# ## < What We Will Do . . . >
# ### **Transform Unstructured data into structured data**

# %% [markdown]
# ![스크린샷 2022-05-21 오전 10.25.00.png](data:image/png;base64,...)

# %% [markdown]
# 부연) 첫 번째 문서가 주어져 있을 때, 첫 번째 변수부터 P 번째 변수까지에 해당하는 고정 길이에다가 주황색 칸에 숫자를 채우는 것. 그 이후에 문서가 들어왔을 때에도 마찬가지이고, 그래서 코퍼스 안에 있는 모든 문서들에 대해서 같은 차원의 연속형 수치형 벡터로 변환하자는 것이 이번 챕터의 목적입니다.

# %% [markdown]
# ## < Bag of Words: Motivation >
# ### Document Representation
# - How to represent a document in a structured way?
# - How to convert ***a unstructured text*** into ***a vector/matrix form*** to apply machine learning algorithms based on a vector space?

# %% [markdown]
# ## < Bag of Words: Idea >
# ### Bag-of-words
# - A simplified representation method for documents where a text is represented in a vector of ***an unordered collection of words***
# - Consider words as atomic symbols, represented in the ***discrete space***

# %% [markdown]
# ![스크린샷 2022-05-21 오전 10.47.55.png](data:image/png;base64,...)

# %% [markdown]
# 부연) "한 번이라도 등장한 단어를 전부 나열하고, 한 문서(한 문장)에서 해당하는 단어가 나온 횟수만큼 표기해 주자"가 BOW의 방식입니다.

# %% [markdown]
# ### Bag-of-words: Term-Document Matrix
# - Simplifying representation method for documents where a text is represented in a vecor of an unordered collection of words
#
# **<center>S1: John likes to watch movies. Mary likes too.</center>**
# **<center>S2: John also likes to watch football game.</center>**

# %% [markdown]
# ![스크린샷 2022-05-21 오전 10.52.35.png](data:image/png;base64,...)

# %% [markdown]
# 부연) BOW 방식의 representation은 크게 Binary와 Frequency가 있습니다. task에 따라 성능이 달라집니다.
# Binary representation은 해당하는 단어가 몇 번 등장하는 것에는 상관없이, 등장의 유무라는 Binary 변수를 사용하겠다는 겁니다.
# Frequency representation은 해당하는 단어가 몇 번 등장하는지에 대한 빈도를 기록하겠다는 겁니다.

# %% [markdown]
# ### Bag of words Representation in a Vector Space
# - The contents can be inferred from the frequency of words
# - Vector representation **does not consider the ordering of words** in a document
#     - Visual words = independent features
#     - ***John is quicker than Mary*** = ***Mary is quicker than John*** in BOW representation
# - We cannot reconstruct the original text based on the term-document matrix

# %% [markdown]
# 부연) 단어의 순서를 고려하지 않기 때문에 나타나는 BOW의 문제점
# 1. 의미가 다른 두 문서(두 문장)가 동일한 representation으로 표현될 가능성이 있다.
# 2. 한번 Bag of words Representation로 표현이 되면 복원이 불가능하다.
