# %% [markdown]
# ## < Feature Selection Metric 8 >
# ### `Information Gain: IG`
# - Measures the **decrease in entropy** when the feature is given vs. absent
# - Entropy without the information provided by the term $w$

# %% [markdown]
# $$ Entropy(absent w) = \sum_{C\in{Pos, Neg}}-P(C) \times log(P(C)) $$

# %% [markdown]
# $IG(w) = Entropy(absent w) - Entropy(given w)$

# %% [markdown]
# - For Term 1
# $Entropy(absent w) = -P(Pos) \times log(P(Pos))-P(Neg)×log(P(Neg)) = -0.6 \times log(0.6) - 0.4 × log(0.4) = 0.29 $
#
# $Entropy(given w) = P(w)[-P(Pos|w)\times log(P(Pos|w)) -P(Neg|w)\times log(P(Neg|w))] + p(\bar{w})[-P(Pos|\bar{w}) \times log(P(Pos|\bar{w})) - P(Neg|\bar{w} \times log(P(Neg|\bar{w}))] = 0.6[-1\times log(1) - 0 \times log(0)] + 0.4[-0 \times log(0) - 1 \times log(1)] = 0$

# %% [markdown]
# $IG(w) = 0.29 - 0 = 0.29$

# %% [markdown]
# ## < Feature Selection Metric 9 >
# ### `Chi-squared statistic (x^2)`
# - Measures divergence from the distribution expected if one assumes the feature occurrence is independent of the class label
#
# $$ x^2(w) = \frac{N \times [P(Pos, w) \times P(Neg, \bar{w}) - P(Neg, w) \times P(Pos, \bar{w})]^2}{P(w)\times P(\bar{w)\times P(Pos)\times P(Neg)}} $$

# %% [markdown]
# ![스크린샷 2022-06-23 오후 5.55.16.png](data:image/png;base64,...)

# %% [markdown]
# $$ x^2(T1) = \frac{10\times[0.6 \times 0.4 - 0 \times 0]^2}{0.6 \times 0.4 \times 0.6 \times 0.4} = 10.00  $$ $$ x^2(T4) = \frac{10\times[0.6 \times 0.2 - 0.2 \times 0]^2}{0.8 \times 0.2 \times 0.6 \times 0.4} = 3.75 $$

# %% [markdown]
# ## < Feature Selection Metric 10 >
# ### `Bi-Normal Separation (BNS)`
# - Measures the degree of separation assuming that the occurrence of a feature in a document is a random process following a normal distribution

# %% [markdown]
# $$ BNS(w) = \left| F^{-1}\frac{N(Pos, w)}{N(Pos)}-F^{-1}\frac{N(Neg, w)}{N(Neg)}     \right| $$

# %% [markdown]
# ![스크린샷 2022-06-23 오후 5.56.13.png](data:image/png;base64,...)

# %% [markdown]
# ## < Feature Selection Metric 8-10 >
# ### Compute the metric 8-10 for the data set

# %% [markdown]
# ![스크린샷 2022-06-23 오후 5.57.00.png](data:image/png;base64,...)
