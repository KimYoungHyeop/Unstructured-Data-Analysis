# %% [markdown]
# ## < Syntax Analysis >

# %% [markdown]
# ### Syntax Analysis
# - Process of analyzing a string of symbols conforming to the rules of a formal grammar

# %% [markdown]
# <center>
#
# ![440px-English_Tree1.png](data:image/png;base64,...)</center>

# %% [markdown]
# ### Parser
# - An algorithm that computes a structure for an input string given a grammar
# 즉, input string들을 가져와서 특정 grammar에 맞게 변환해 주는 알고리즘을 말합니다.
# - All parsers have two fundamental propeties
#     - `Directionality`: the sequence in which the structures are contructed (e.g., top-down or bottom-up)
#     - `Search strategy`: the order in which the search space of possible analysis explored (e.g., depth-first, breadth-first)

# %% [markdown]
# ### Parsing Representation
# #### Tree vs List

# %% [markdown]
# <center>< Tree >
#
# ![main-qimg-7bb525fbbffb206352da54bcbf2a2422.webp](data:image/webp;base64,...)</center>

# %% [markdown]
# <center>< List >
#
# ![스크린샷 2022-05-12 오후 11.39.45.png](data:image/png;base64,...)</center>

# %% [markdown]
# #### Meaning
# - **S** (**S**entence) consists of **NP** (**N**oun **P**hrase) and **VP** (**V**erb **P**hrase)
# - **NP** consists of Name (John)
# - **VP** consists of **VERB** (ate) and the other **NP**
# - **NP** consists of **ART** (the) and Noun (apple)

# %% [markdown]
# ### Not a single parsing tree due to language ambiguity
# ### Lexical ambiguity
#   - One word can be used for multiple parts of speech
#   - Lexical ambiguity causes structural ambiguity

# %% [markdown]
# <center>
#
# ![스크린샷 2022-05-12 오후 11.48.39.png](data:image/png;base64,...)<center>

# %% [markdown]
# #### Structural Ambiguity
# - One sentence can be understood in different ways

# %% [markdown]
# <center>
#
# ![스크린샷 2022-05-12 오후 11.51.05.png](data:image/png;base64,...)</center>
